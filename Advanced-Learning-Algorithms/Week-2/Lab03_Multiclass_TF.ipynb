# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
np.set_printoptions(precision=2)
from lab_utils_multiclass_TF import *
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

# %%
# make 4-class dataset for classification
classes = 4
m = 100
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
std = 1.
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)

# %%
plt_mc(X_train,y_train,classes, centers, std=std)
# Out:
# c:\Users\tvrdy\Desktop\Python ML\Machine-Learning-Specialization\Advanced-Learning-Algorithms\Week-2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# show classes in data set
print(f"unique classes {np.unique(y_train)}")
# show how classes are represented
print(f"class representation {y_train[:10]}")
# show shapes of our dataset
print(f"shape of X_train: {X_train.shape}, shape of y_train: {y_train.shape}")
# Out:
# unique classes [0 1 2 3]
# class representation [3 3 3 0 3 3 3 3 2 0]
# shape of X_train: (100, 2), shape of y_train: (100,)

# %%
tf.random.set_seed(1234)    # applied to achieve consistent results
model = Sequential(
    [
        Dense(2, activation='relu', name='L1'),
        Dense(4, activation='linear', name='L2')
    ]
)

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)
model.fit(X_train,y_train,epochs=200)
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.3383
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0301
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 1.7820
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5794
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 1.4161
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2832
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1787
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 1.0968
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0344
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.9863
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9480
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.9166
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - loss: 0.8901
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8670
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.8465
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.8277
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.8102
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.7937
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.7778
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7626
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.7479
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.7339
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7205
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - loss: 0.7078
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6956
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6840
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6727
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6618
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6513
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6412
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6314
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6220
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6128
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6039
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - loss: 0.5952
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.5868
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - loss: 0.5786
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5706
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 0.5628
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5550
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5474
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5399
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5324
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5249
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5175
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.5102
# Epoch 47/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.5030
# Epoch 48/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.4958
# Epoch 49/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.4886
# Epoch 50/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4815
# Epoch 51/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.4745
# Epoch 52/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - loss: 0.4675
# Epoch 53/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.4605
# Epoch 54/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4535
# Epoch 55/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.4464
# Epoch 56/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.4394
# Epoch 57/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4324
# Epoch 58/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4253
# Epoch 59/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4181
# Epoch 60/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4106
# Epoch 61/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.4031
# Epoch 62/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3956
# Epoch 63/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.3879
# Epoch 64/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3799
# Epoch 65/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.3718
# Epoch 66/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.3637
# Epoch 67/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.3557
# Epoch 68/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.3478
# Epoch 69/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.3400
# Epoch 70/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.3325
# Epoch 71/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3251
# Epoch 72/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3179
# Epoch 73/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3109
# Epoch 74/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3041
# Epoch 75/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 0.2975
# Epoch 76/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2911
# Epoch 77/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.2849
# Epoch 78/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.2786
# Epoch 79/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - loss: 0.2723
# Epoch 80/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - loss: 0.2662
# Epoch 81/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2601
# Epoch 82/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2543
# Epoch 83/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2485
# Epoch 84/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.2430
# Epoch 85/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - loss: 0.2377
# Epoch 86/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2325
# Epoch 87/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2275
# Epoch 88/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2226
# Epoch 89/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2179
# Epoch 90/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2134
# Epoch 91/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.2090
# Epoch 92/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2047
# Epoch 93/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.2006
# Epoch 94/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1967
# Epoch 95/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1928
# Epoch 96/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.1891
# Epoch 97/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1855
# Epoch 98/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1821
# Epoch 99/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1787
# Epoch 100/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1755
# Epoch 101/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1724
# Epoch 102/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1693
# Epoch 103/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1664
# Epoch 104/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1634
# Epoch 105/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.1596
# Epoch 106/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.1556
# Epoch 107/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1514
# Epoch 108/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1472
# Epoch 109/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1432
# Epoch 110/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1393
# Epoch 111/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1355
# Epoch 112/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1319
# Epoch 113/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1285
# Epoch 114/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1252
# Epoch 115/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1221
# Epoch 116/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1191
# Epoch 117/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1162
# Epoch 118/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.1134
# Epoch 119/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1107
# Epoch 120/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1082
# Epoch 121/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 0.1057
# Epoch 122/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1033
# Epoch 123/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1010
# Epoch 124/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0988
# Epoch 125/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.0967
# Epoch 126/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0947
# Epoch 127/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 0.0927
# Epoch 128/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0908
# Epoch 129/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0890
# Epoch 130/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0873
# Epoch 131/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0856
# Epoch 132/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0839
# Epoch 133/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0823
# Epoch 134/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0808
# Epoch 135/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0793
# Epoch 136/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0779
# Epoch 137/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0765
# Epoch 138/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0751
# Epoch 139/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0738
# Epoch 140/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.0725
# Epoch 141/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.0713
# Epoch 142/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.0701
# Epoch 143/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.0689
# Epoch 144/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - loss: 0.0677
# Epoch 145/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0666
# Epoch 146/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0656
# Epoch 147/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0645
# Epoch 148/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0635
# Epoch 149/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0625
# Epoch 150/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0616
# Epoch 151/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0606
# Epoch 152/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0597
# Epoch 153/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0588
# Epoch 154/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0580
# Epoch 155/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0571
# Epoch 156/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0563
# Epoch 157/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0555
# Epoch 158/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547
# Epoch 159/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0539
# Epoch 160/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0532
# Epoch 161/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0525
# Epoch 162/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0517
# Epoch 163/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.0511
# Epoch 164/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0504
# Epoch 165/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0497
# Epoch 166/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0491
# Epoch 167/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0484
# Epoch 168/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0478
# Epoch 169/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.0472
# Epoch 170/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 0.0466
# Epoch 171/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0460
# Epoch 172/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0455
# Epoch 173/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0449
# Epoch 174/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0444
# Epoch 175/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.0438
# Epoch 176/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0433
# Epoch 177/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0428
# Epoch 178/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0423
# Epoch 179/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0418
# Epoch 180/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0413
# Epoch 181/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0409
# Epoch 182/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0404
# Epoch 183/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0400
# Epoch 184/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0395
# Epoch 185/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0391
# Epoch 186/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0387
# Epoch 187/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0383
# Epoch 188/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0378
# Epoch 189/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0374
# Epoch 190/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0370
# Epoch 191/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0367
# Epoch 192/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0363
# Epoch 193/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.0359
# Epoch 194/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0355
# Epoch 195/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0352
# Epoch 196/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0348
# Epoch 197/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0345
# Epoch 198/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0341
# Epoch 199/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - loss: 0.0338
# Epoch 200/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.0335

# %%
plt_cat_mc(X_train,y_train,model,classes)
# Out:
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the first layer
l1 = model.get_layer("L1")
W1,b1 = l1.get_weights()

# %%
# plot the function of the first layer
plt_layer_relu(X_train,y_train.reshape(-1,),W1,b1,classes)
# Out:
# c:\Users\tvrdy\Desktop\Python ML\Machine-Learning-Specialization\Advanced-Learning-Algorithms\Week-2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# c:\Users\tvrdy\Desktop\Python ML\Machine-Learning-Specialization\Advanced-Learning-Algorithms\Week-2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the output layer
l2 = model.get_layer("L2")
W2,b2 = l2.get_weights()
# create the 'new features', the training examples after L1 transformation
Xl2 = np.maximum(0,np.dot(X_train,W1)+b1)

plt_output_layer_linear(Xl2,y_train.reshape(-1,),W2,b2,classes,
                        x0_rng=(-0.25,np.amax(Xl2[:,0])), x1_rng=(-0.25,np.amax(Xl2[:,1])))
# Out:
# c:\Users\tvrdy\Desktop\Python ML\Machine-Learning-Specialization\Advanced-Learning-Algorithms\Week-2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# c:\Users\tvrdy\Desktop\Python ML\Machine-Learning-Specialization\Advanced-Learning-Algorithms\Week-2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# c:\Users\tvrdy\Desktop\Python ML\Machine-Learning-Specialization\Advanced-Learning-Algorithms\Week-2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# c:\Users\tvrdy\Desktop\Python ML\Machine-Learning-Specialization\Advanced-Learning-Algorithms\Week-2\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …
